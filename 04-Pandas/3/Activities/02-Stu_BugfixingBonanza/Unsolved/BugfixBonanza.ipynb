# %%
import pandas as pd

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
csv_path = "../Resources/EclipseBugs.csv"
eclipse_df = pd.read_csv(csv_path)

# %%
eclipse_df.columns
# Out:
# Index(['Bug\nID', 'Product', 'Component Bug Count', 'Assignee', 'Status',
#        'Resolution', 'Summary', 'Changed', 'Assignee\nReal\nName',
#        'Classification', 'Hardware', 'Number of Comments', 'Opened', 'OS',
#        'Priority', 'Reporter', 'Reporter\nReal\nName', 'Severity',
#        'Target\nMilestone', 'Version', 'Votes'],
#       dtype='object')

# %%
eclipse_df = eclipse_df.rename(columns = {'Number of\nComments':'Number of Comments'})
eclipse_df.head()
# Out:
#    Bug\nID Product Component Bug Count Assignee    Status Resolution  \
# 0     3638     JDT                  UI  aeschli  VERIFIED      FIXED
# 1     3854     JDT                  UI  aeschli  VERIFIED      FIXED
# 2     4188     JDT                  UI  aeschli  VERIFIED      FIXED
# 3     5115     JDT               Debug  aeschli  VERIFIED      FIXED
# 4     5820     JDT                  UI  aeschli  VERIFIED      FIXED
#
#                                              Summary           Changed  \
# 0  Package Viewer: order resource folders before ...    1/17/2002 7:28
# 1             Wrong execution's classpath. (1GEY0W0)    1/18/2002 4:02
# 2                     type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3  Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4    Close all editors brings up hierarchy of object  11/20/2001 16:22
#
#   Assignee\nReal\nName Classification  ...  Number of Comments  \
# 0   Martin Aeschlimann        Eclipse  ...                   3
# 1   Martin Aeschlimann        Eclipse  ...                   5
# 2   Martin Aeschlimann        Eclipse  ...                   3
# 3   Martin Aeschlimann        Eclipse  ...                  10
# 4   Martin Aeschlimann        Eclipse  ...                   5
#
#              Opened            OS Priority       Reporter  \
# 0  10/10/2001 22:58    Windows NT       P1        aeschli
# 1  10/10/2001 23:01    Windows NT       P1    david_audel
# 2  10/10/2001 23:07  Windows 2000       P1    erich_gamma
# 3  10/19/2001 13:41  Windows 2000       P1  darin.eclipse
# 4  11/12/2001 18:18  Windows 2000       P1   jed.anderson
#
#   Reporter\nReal\nName Severity Target\nMilestone Version Votes
# 0   Martin Aeschlimann    major               ---       2     0
# 1          David Audel   normal               ---       2     0
# 2          Erich Gamma   normal               ---       2     0
# 3         Darin Wright   normal               ---       2     0
# 4         Jed Anderson   normal               ---       2     0
#
# [5 rows x 21 columns]

# %%
eclipse_df.columns
# Out:
# Index(['Bug\nID', 'Product', 'Component Bug Count', 'Assignee', 'Status',
#        'Resolution', 'Summary', 'Changed', 'Assignee\nReal\nName',
#        'Classification', 'Hardware', 'Number of Comments', 'Opened', 'OS',
#        'Priority', 'Reporter', 'Reporter\nReal\nName', 'Severity',
#        'Target\nMilestone', 'Version', 'Votes'],
#       dtype='object')

# %%
# Finding the average number of comments per bug

average_comments = eclipse_df["Number of Comments"].mean()
average_comments
# Out:
# 8.75

# %%
# Grouping the DataFrame by "Assignee"
assignee_group = eclipse_df.groupby("Assignee")

# Count how many of each component Assignees worked on and create DataFrame
assignee_work["Component Bug Count"] = pd.DataFrame(assignee_group["Component"].value_counts())
assignee_work.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-ae43136607ca> in <module>()
#       3
#       4 # Count how many of each component Assignees worked on and create DataFrame
# ----> 5 assignee_work["Component Bug Count"] = pd.DataFrame(assignee_group["Component"].value_counts())
#       6 assignee_work.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     352         else:
#     353             if key not in self.obj:
# --> 354                 raise KeyError("Column not found: %s" % key)
#     355             return self._gotitem(key, ndim=1)
#     356
#
# KeyError: 'Column not found: Component'

# %%
assignee_work.columns
# Out:
# Index(['Component'], dtype='object')

# %%
# Rename the "Component" column to "Component Bug Count"
eclipse_df = eclipse_df.rename(columns = {'Component':'Component Bug Count'}, inplace=False)
eclipse_df
# Out:
#       Bug\nID   Product Component Bug Count       Assignee    Status  \
# 0        3638       JDT                  UI        aeschli  VERIFIED
# 1        3854       JDT                  UI        aeschli  VERIFIED
# 2        4188       JDT                  UI        aeschli  VERIFIED
# 3        5115       JDT               Debug        aeschli  VERIFIED
# 4        5820       JDT                  UI        aeschli  VERIFIED
# 5        6441       JDT                  UI        aeschli  VERIFIED
# 6        7329       JDT                  UI        aeschli  VERIFIED
# 7        7966       JDT                  UI        aeschli  VERIFIED
# 8        8224       JDT                  UI        aeschli  VERIFIED
# 9        8280       JDT                  UI        aeschli  VERIFIED
# 10      10929       JDT                  UI        aeschli  VERIFIED
# 11      24911       JDT                  UI        aeschli  VERIFIED
# 12      30991       JDT                  UI        aeschli  VERIFIED
# 13      32831       JDT                  UI        aeschli  VERIFIED
# 14      43518       JDT                  UI        aeschli  VERIFIED
# 15      44425       JDT                  UI        aeschli  VERIFIED
# 16     188521  Platform     User Assistance       agarcher  VERIFIED
# 17       6341       JDT                  UI        akiezun  VERIFIED
# 18       7046       JDT                  UI        akiezun  VERIFIED
# 19       7317       JDT                  UI        akiezun  VERIFIED
# 20       7639       JDT                  UI        akiezun  VERIFIED
# 21       7873       JDT                  UI        akiezun  VERIFIED
# 22       8023       JDT                  UI        akiezun  VERIFIED
# 23       8129       JDT                  UI        akiezun  VERIFIED
# 24       8730       JDT                  UI        akiezun  VERIFIED
# 25      11424       JDT                  UI        akiezun  VERIFIED
# 26      16283  Platform             Compare        akiezun  VERIFIED
# 27      18071       JDT                  UI        akiezun  VERIFIED
# 28      18079       JDT                  UI        akiezun  VERIFIED
# 29      18276       JDT                  UI        akiezun  VERIFIED
# ...       ...       ...                 ...            ...       ...
# 9970    66058  Platform                 Ant  darin.eclipse  VERIFIED
# 9971    66417       JDT               Debug  darin.eclipse  VERIFIED
# 9972    66453       JDT               Debug  darin.eclipse  VERIFIED
# 9973    66576  Platform               Debug  darin.eclipse  VERIFIED
# 9974    66867  Platform               Debug  darin.eclipse  VERIFIED
# 9975    67463  Platform               Debug  darin.eclipse  VERIFIED
# 9976    68132  Platform                 Ant  darin.eclipse  VERIFIED
# 9977    68621  Platform               Debug  darin.eclipse  VERIFIED
# 9978    68808  Platform               Debug  darin.eclipse  VERIFIED
# 9979    68809       JDT               Debug  darin.eclipse  VERIFIED
# 9980    68840  Platform                 Ant  darin.eclipse  VERIFIED
# 9981    69083  Platform               Debug  darin.eclipse  VERIFIED
# 9982    69235  Platform                 Ant  darin.eclipse  VERIFIED
# 9983    69736       JDT               Debug  darin.eclipse  VERIFIED
# 9984    69815  Platform               Debug  darin.eclipse  VERIFIED
# 9985    69818       JDT               Debug  darin.eclipse  VERIFIED
# 9986    70238  Platform                 Ant  darin.eclipse  VERIFIED
# 9987    70472  Platform               Debug  darin.eclipse  VERIFIED
# 9988    70492  Platform               Debug  darin.eclipse  VERIFIED
# 9989    70493  Platform               Debug  darin.eclipse  VERIFIED
# 9990    70495  Platform               Debug  darin.eclipse  VERIFIED
# 9991    70499  Platform               Debug  darin.eclipse  VERIFIED
# 9992    70629       JDT               Debug  darin.eclipse  VERIFIED
# 9993    70664  Platform               Debug  darin.eclipse  VERIFIED
# 9994    70841  Platform                 Ant  darin.eclipse  VERIFIED
# 9995    70864  Platform               Debug  darin.eclipse  VERIFIED
# 9996    70955       JDT               Debug  darin.eclipse  VERIFIED
# 9997    71149  Platform               Debug  darin.eclipse  VERIFIED
# 9998    71292  Platform               Debug  darin.eclipse  VERIFIED
# 9999    71296  Platform                 Ant  darin.eclipse  VERIFIED
#
#      Resolution                                            Summary  \
# 0         FIXED  Package Viewer: order resource folders before ...
# 1         FIXED             Wrong execution's classpath. (1GEY0W0)
# 2         FIXED                     type hierachy - typo (1GJW2XJ)
# 3         FIXED  Workspace source locator fails with mulitple p...
# 4         FIXED    Close all editors brings up hierarchy of object
# 5         FIXED      "Plugins containing only Jars" logis reverted
# 6         FIXED  Outline view: wrong spelling "Add JavDoc Comment"
# 7         FIXED       Class Creation Dialog generates syntax error
# 8         FIXED  Organize imports adds explicit import to wildc...
# 9         FIXED      Package view back/forward/up arrow hover help
# 10        FIXED           All types cache is flushed to frequently
# 11        FIXED  quick fix: NPE on 'change visibility to defaul...
# 12        FIXED                     NPE in New Java Project Wizard
# 13        FIXED          NPE buildpaths.CPVariableElement.equals()
# 14        FIXED  Stepping through session bean is very slow in ...
# 15        FIXED  Illegal code in the code formatter preference ...
# 16        FIXED  [Webapp] Test F1: 2)  Standalone infocenter no...
# 17        FIXED               NullPointerException from ReorgGroup
# 18        FIXED  NPE trying to show context menu on method in O...
# 19        FIXED                     ClassCastException during move
# 20        FIXED                 NPE when renaming a local variable
# 21        FIXED                               Bogus error messages
# 22        FIXED  coreexception when draging packages to its own...
# 23        FIXED                      NPE in Extract Local Variable
# 24        FIXED               wrong method deleted (packages view)
# 25        FIXED  ArrayIndexOutOfBoundsException at "Expand Sele...
# 26        FIXED          Add from Local History items are unsorted
# 27        FIXED                 Package Viewer: Too many refreshes
# 28        FIXED  We must guard our Action against a Java editor...
# 29        FIXED  Java Search action set is missing the name for...
# ...         ...                                                ...
# 9970      FIXED             Change project builder "handle" format
# 9971      FIXED  VMDisconnectedException logged from source lookup
# 9972      FIXED  String concatenation gives unexpected result i...
# 9973      FIXED  perspectives pref page tab does not take activ...
# 9974      FIXED                                    icon allignment
# 9975      FIXED               Launch Shortcuts schema is incorrect
# 9976      FIXED  [Readme] How to build with buildfiles that con...
# 9977      FIXED  Invalid thread access in launcher from Checkou...
# 9978      FIXED  all debug actions (step, terminate, etc), shou...
# 9979      FIXED         Support for breakpoints in 1.5 source code
# 9980      FIXED  Source not found on Console hyperlink for Sepa...
# 9981      FIXED     Switch to associated perspective on suspension
# 9982      FIXED               Fully qualify the Ant partition name
# 9983      FIXED  IWAV0138E Remote VM terminated too soon error ...
# 9984      FIXED  DBCS -- System console cannot display Unicode ...
# 9985      FIXED                   NPE when launching with Debugger
# 9986      FIXED  Clicking junit call stack items doesn't open s...
# 9987      FIXED        MemoryBlockManager has redundant null check
# 9988      FIXED           Possible NPE in AddSourceContainerDialog
# 9989      FIXED               Possible NPE in ViewTabCursorManager
# 9990      FIXED                 Redundant null check in RefreshTab
# 9991      FIXED  Unnecessary null check in ContextualLaunchActi...
# 9992      FIXED     [J2SE 5] JDI support for extensible connectors
# 9993      FIXED  TVT3.0:   Improper characters combination "Run...
# 9994      FIXED                                  Move to Ant 1.6.2
# 9995      FIXED     API method to show the console view has a bug.
# 9996      FIXED   Empty string as a program argument not accepted.
# 9997      FIXED  [artwork] When breakpoints are disabled (skipp...
# 9998      FIXED               Launch name is truncated in MRU list
# 9999      FIXED     Ant editor performance tests: opening / typing
#
#                Changed Assignee\nReal\nName Classification  ...   \
# 0       1/17/2002 7:28   Martin Aeschlimann        Eclipse  ...
# 1       1/18/2002 4:02   Martin Aeschlimann        Eclipse  ...
# 2       1/28/2002 3:12   Martin Aeschlimann        Eclipse  ...
# 3     11/13/2001 10:11   Martin Aeschlimann        Eclipse  ...
# 4     11/20/2001 16:22   Martin Aeschlimann        Eclipse  ...
# 5       1/16/2002 2:58   Martin Aeschlimann        Eclipse  ...
# 6       1/15/2002 5:56   Martin Aeschlimann        Eclipse  ...
# 7       3/28/2002 5:43   Martin Aeschlimann        Eclipse  ...
# 8       2/13/2002 8:38   Martin Aeschlimann        Eclipse  ...
# 9       2/13/2002 7:51   Martin Aeschlimann        Eclipse  ...
# 10      3/20/2002 8:18   Martin Aeschlimann        Eclipse  ...
# 11     11/14/2002 9:01   Martin Aeschlimann        Eclipse  ...
# 12     2/24/2003 10:28   Martin Aeschlimann        Eclipse  ...
# 13     3/19/2003 10:43   Martin Aeschlimann        Eclipse  ...
# 14     10/17/2003 5:27   Martin Aeschlimann        Eclipse  ...
# 15     10/8/2003 17:44   Martin Aeschlimann        Eclipse  ...
# 16      6/11/2007 9:50          Adam Archer        Eclipse  ...
# 17      1/16/2002 2:31          Adam Kiezun        Eclipse  ...
# 18      1/15/2002 6:14          Adam Kiezun        Eclipse  ...
# 19      1/15/2002 5:53          Adam Kiezun        Eclipse  ...
# 20      2/13/2002 8:29          Adam Kiezun        Eclipse  ...
# 21      3/28/2002 5:22          Adam Kiezun        Eclipse  ...
# 22      2/13/2002 6:29          Adam Kiezun        Eclipse  ...
# 23      3/28/2002 6:49          Adam Kiezun        Eclipse  ...
# 24     3/28/2002 10:39          Adam Kiezun        Eclipse  ...
# 25      3/28/2002 4:00          Adam Kiezun        Eclipse  ...
# 26       6/3/2002 6:38          Adam Kiezun        Eclipse  ...
# 27       6/5/2002 7:47          Adam Kiezun        Eclipse  ...
# 28       6/3/2002 6:32          Adam Kiezun        Eclipse  ...
# 29       6/3/2002 6:24          Adam Kiezun        Eclipse  ...
# ...                ...                  ...            ...  ...
# 9970   6/10/2004 17:55         Darin Wright        Eclipse  ...
# 9971  10/28/2004 13:54         Darin Wright        Eclipse  ...
# 9972   11/8/2004 16:55         Darin Wright        Eclipse  ...
# 9973   2/10/2006 14:36         Darin Wright        Eclipse  ...
# 9974   6/15/2004 16:25         Darin Wright        Eclipse  ...
# 9975   6/17/2004 12:43         Darin Wright        Eclipse  ...
# 9976    8/5/2004 11:18         Darin Wright        Eclipse  ...
# 9977  11/11/2004 16:12         Darin Wright        Eclipse  ...
# 9978    8/5/2004 11:13         Darin Wright        Eclipse  ...
# 9979   11/9/2004 18:22         Darin Wright        Eclipse  ...
# 9980    1/5/2005 19:24         Darin Wright        Eclipse  ...
# 9981   11/1/2004 10:41         Darin Wright        Eclipse  ...
# 9982    8/6/2004 17:38         Darin Wright        Eclipse  ...
# 9983   9/30/2004 11:44         Darin Wright        Eclipse  ...
# 9984   11/1/2004 10:14         Darin Wright        Eclipse  ...
# 9985   7/21/2004 17:32         Darin Wright        Eclipse  ...
# 9986   1/17/2005 11:14         Darin Wright        Eclipse  ...
# 9987   7/22/2004 10:40         Darin Wright        Eclipse  ...
# 9988   7/22/2004 10:43         Darin Wright        Eclipse  ...
# 9989   7/22/2004 10:49         Darin Wright        Eclipse  ...
# 9990   7/22/2004 10:51         Darin Wright        Eclipse  ...
# 9991   7/22/2004 10:53         Darin Wright        Eclipse  ...
# 9992   12/3/2004 15:03         Darin Wright        Eclipse  ...
# 9993  12/20/2004 12:32         Darin Wright        Eclipse  ...
# 9994    4/26/2005 2:43         Darin Wright        Eclipse  ...
# 9995   8/20/2004 14:42         Darin Wright        Eclipse  ...
# 9996  10/29/2004 10:27         Darin Wright        Eclipse  ...
# 9997   1/14/2005 17:06         Darin Wright        Eclipse  ...
# 9998   8/20/2004 15:00         Darin Wright        Eclipse  ...
# 9999   10/15/2004 9:30         Darin Wright        Eclipse  ...
#
#      Number of Comments            Opened            OS Priority  \
# 0                     3  10/10/2001 22:58    Windows NT       P1
# 1                     5  10/10/2001 23:01    Windows NT       P1
# 2                     3  10/10/2001 23:07  Windows 2000       P1
# 3                    10  10/19/2001 13:41  Windows 2000       P1
# 4                     5  11/12/2001 18:18  Windows 2000       P1
# 5                     2  11/29/2001 13:50  Windows 2000       P1
# 6                     2     1/8/2002 2:44    Windows NT       P1
# 7                     4   1/21/2002 15:42  Windows 2000       P1
# 8                     4   1/23/2002 13:42         other       P1
# 9                     7   1/23/2002 15:25  Windows 2000       P1
# 10                    6     3/7/2002 4:45  Windows 2000       P1
# 11                    5   10/17/2002 5:56  Windows 2000       P1
# 12                    5    2/5/2003 12:51    Windows XP       P1
# 13                    5   2/24/2003 17:12   Linux-Motif       P1
# 14                   14   9/23/2003 11:52  Windows 2000       P1
# 15                    9    10/8/2003 9:07  Windows 2000       P1
# 16                   15   5/22/2007 20:12           All       P1
# 17                    2   11/27/2001 5:58  Windows 2000       P1
# 18                    2  12/18/2001 10:49         other       P1
# 19                    2    1/7/2002 14:05  Windows 2000       P1
# 20                    3   1/15/2002 14:44  Windows 2000       P1
# 21                    5   1/17/2002 17:37    Windows NT       P1
# 22                    6   1/22/2002 12:32  Windows 2000       P1
# 23                    3   1/23/2002 10:12  Windows 2000       P1
# 24                    4    1/30/2002 5:35  Windows 2000       P1
# 25                    5   3/14/2002 20:16  Windows 2000       P1
# 26                    8   5/17/2002 13:29  Windows 2000       P1
# 27                    8   5/28/2002 12:16  Windows 2000       P1
# 28                    5   5/28/2002 13:13  Windows 2000       P1
# 29                    5    5/30/2002 0:32  Windows 2000       P1
# ...                 ...               ...           ...      ...
# 9970                 15    6/7/2004 18:43           All       P3
# 9971                  6    6/9/2004 16:48  Windows 2000       P3
# 9972                  7    6/9/2004 23:03  Windows 2000       P3
# 9973                 14   6/10/2004 15:43           All       P3
# 9974                  5   6/13/2004 10:57    Windows XP       P3
# 9975                  7   6/16/2004 11:09    Windows XP       P3
# 9976                  4   6/21/2004 21:53    Windows XP       P3
# 9977                  5   6/25/2004 11:06    Windows XP       P3
# 9978                 11   6/28/2004 15:03    Windows XP       P3
# 9979                  5   6/28/2004 15:05    Windows XP       P3
# 9980                 15    6/29/2004 5:20    Windows XP       P3
# 9981                 17   6/30/2004 17:29           All       P3
# 9982                  4    7/2/2004 23:16    Windows XP       P3
# 9983                 19    7/9/2004 11:56    Windows XP       P3
# 9984                 18    7/12/2004 5:33    Windows XP       P3
# 9985                 11    7/12/2004 7:02    Windows XP       P3
# 9986                 14   7/16/2004 11:27  Windows 2000       P3
# 9987                  3   7/20/2004 15:38           All       P3
# 9988                  3   7/20/2004 18:08           All       P3
# 9989                  4   7/20/2004 18:13           All       P3
# 9990                  4   7/20/2004 18:18           All       P3
# 9991                  3   7/20/2004 18:32           All       P3
# 9992                  6   7/22/2004 11:23    Windows XP       P3
# 9993                 13   7/22/2004 13:45         Linux       P3
# 9994                  9   7/26/2004 14:20    Windows XP       P3
# 9995                  4   7/26/2004 18:11    Windows XP       P3
# 9996                 10    7/28/2004 3:29    Windows NT       P3
# 9997                 17    7/30/2004 7:59    Windows XP       P3
# 9998                  7    8/3/2004 11:11    Windows XP       P3
# 9999                  5    8/3/2004 11:41    Windows XP       P3
#
#              Reporter     Reporter\nReal\nName     Severity Target\nMilestone  \
# 0             aeschli       Martin Aeschlimann        major               ---
# 1         david_audel              David Audel       normal               ---
# 2         erich_gamma              Erich Gamma       normal               ---
# 3       darin.eclipse             Darin Wright       normal               ---
# 4        jed.anderson             Jed Anderson       normal               ---
# 5         erich_gamma              Erich Gamma       normal               ---
# 6       daniel_megert              Dani Megert       normal               ---
# 7         Tod_Creasey              Tod Creasey       normal               ---
# 8        knut_radloff             Knut Radloff       normal               ---
# 9          jeff_brown               Jeff Brown       normal               ---
# 10        erich_gamma              Erich Gamma       normal            2.0 M4
# 11            akiezun              Adam Kiezun        major            2.1 M3
# 12          csmclaren            Chris McLaren     critical           2.1 RC1
# 13            airvine            Andrew Irvine       normal           2.1 RC2
# 14           stevenyj               Steven Jin     critical             2.1.2
# 15    Olivier_Thomann          Olivier Thomann      blocker            3.0 M4
# 16            mpawlow           Mike Pawlowski       normal           3.3 RC2
# 17            aeschli       Martin Aeschlimann       normal               ---
# 18            eclipse          Joe Szurszewski       normal               ---
# 19           fraenkel         Michael Fraenkel       normal               ---
# 20       Ian_Petersen             Ian Petersen       normal               ---
# 21         lynne_kues               Lynne Kues       normal               ---
# 22            aeschli       Martin Aeschlimann        major               ---
# 23            aeschli       Martin Aeschlimann       normal               ---
# 24            akiezun              Adam Kiezun        major               ---
# 25               rele           Rene Leonhardt       normal               ---
# 26         nick_edgar               Nick Edgar     critical            2.0 F2
# 27            aeschli       Martin Aeschlimann        major            2.0 F2
# 28       dirk_baeumer             Dirk Baeumer     critical            2.0 F2
# 29         nick_edgar               Nick Edgar       normal            2.0 F2
# ...               ...                      ...          ...               ...
# 9970      jared_burns              Jared Burns       normal           3.0 RC2
# 9971     saumit.sheth             Saumit Sheth        major            3.1 M3
# 9972       nick_edgar               Nick Edgar       normal            3.1 M4
# 9973         curtispd       Curtis d'Entremont       normal            3.2 M5
# 9974    darin.eclipse             Darin Wright       normal           3.0 RC3
# 9975            dejan             Dejan Glozic       normal           3.0 RC3
# 9976    Darin_Swanson            Darin Swanson       normal           3.0 RC4
# 9977         valentam          Michael Valenta        minor            3.1 M4
# 9978    darin.eclipse             Darin Wright  enhancement               3.1
# 9979    darin.eclipse             Darin Wright  enhancement            3.1 M3
# 9980       rsontowski          Rafal Sontowski       normal            3.1 M1
# 9981      mikhailkhod      Mikhail Khodjaiants  enhancement            3.1 M3
# 9982    Darin_Swanson            Darin Swanson       normal            3.1 M1
# 9983            ying1                Ying Chen        major             3.0.1
# 9984          xjhuang                    Billy        major            3.1 M3
# 9985       jfrantzius      Jörg von  Frantzius       normal             3.0.1
# 9986             user              Brad Clarke       normal            3.1 M5
# 9987      jared_burns              Jared Burns       normal               3.1
# 9988      jared_burns              Jared Burns       normal               3.1
# 9989      jared_burns              Jared Burns       normal               3.1
# 9990      jared_burns              Jared Burns       normal               3.1
# 9991      jared_burns              Jared Burns       normal               3.1
# 9992    darin.eclipse             Darin Wright  enhancement            3.1 M4
# 9993           dwhare             David W Hare        major               3.1
# 9994    Darin_Swanson            Darin Swanson       normal             3.0.1
# 9995         bagrodia         Saurabh Bagrodia        minor               3.1
# 9996       paul.smith               Paul Smith        minor            3.1 M3
# 9997         acuretra  Thorbjørn Ravn Andersen  enhancement            3.1 M5
# 9998      dj.houghton              DJ Houghton       normal            3.1 M2
# 9999    Darin_Swanson            Darin Swanson       normal            3.1 M2
#
#      Version Votes
# 0          2     0
# 1          2     0
# 2          2     0
# 3          2     0
# 4          2     0
# 5          2     0
# 6          2     0
# 7          2     0
# 8          2     0
# 9          2     0
# 10         2     0
# 11         2     0
# 12       2.1     0
# 13       2.1     0
# 14     2.1.1     0
# 15         3     0
# 16       3.3     0
# 17         2     0
# 18         2     0
# 19         2     0
# 20         2     0
# 21         2     0
# 22         2     0
# 23         2     0
# 24         2     0
# 25         2     0
# 26         2     0
# 27         2     0
# 28         2     0
# 29         2     0
# ...      ...   ...
# 9970       3     0
# 9971       3     0
# 9972       3     0
# 9973       3     0
# 9974       3     0
# 9975       3     0
# 9976       3     0
# 9977       3     0
# 9978       3     0
# 9979       3     0
# 9980       3     0
# 9981       3     0
# 9982       3     0
# 9983       3     0
# 9984       3     0
# 9985       3     0
# 9986     3.1     0
# 9987       3     0
# 9988       3     0
# 9989       3     0
# 9990       3     0
# 9991       3     0
# 9992       3     0
# 9993       3     0
# 9994       3     0
# 9995       3     0
# 9996       3     0
# 9997       3     0
# 9998       3     0
# 9999       3     0
#
# [10000 rows x 21 columns]

# %%
# Find the percentage of bugs overall fixed by each Assignee
total_bugs = assignee_group["Assignee"].count()
bugs_per_user = assignee_group["Assignee"].value_counts()

user_bug_percent = pd.DataFrame((bugs_per_user/total_bugs)*100)
user_bug_percent.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-35d862aff97d> in <module>()
#       1 # Find the percentage of bugs overall fixed by each Assignee
# ----> 2 total_bugs = assignee_group["Assignee"].count()
#       3 bugs_per_user = assignee_group["Assignee"].value_counts()
#
# NameError: name 'assignee_group' is not defined

# %%
# Merge the "Percent of Total Bugs Assigned" into the DataFrame
assignee_work = assignee_work.merge(user_bug_percent,on="Assignee")

# Remove the extra columns
assignee_work = assignee_work[["Assignee","Percent of Total Bugs","Component","Component Bug Count"]]
assignee_work.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3776ea469fab> in <module>()
#       1 # Merge the "Bug Percentages" into the DataFrame
# ----> 2 assignee_work.merge(user_bug_percent,on="Assignee")
#
# NameError: name 'assignee_work' is not defined
